# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data= pd.read_csv("C:\\Users\\vishn\\Documents\\AI\\project\\Non Customers.csv",engine="python")

# %%
data.head()
# Out:
#    CustomerID Title FirstName MiddleName LastName            BirthDate  \
# 0       27489   NaN     Haley        NaN     Hall  1951-08-14 00:00:00
# 1       20417   NaN     Bruce          P  Vazquez  1950-02-11 00:00:00
# 2       20106   NaN     Amber        NaN     Hall  1957-09-21 00:00:00
# 3       28475   NaN     Bruce        NaN    Ramos  1941-06-11 00:00:00
# 4       19528   NaN    Bailey          C     Hall  1967-05-14 00:00:00
#
#   MaritalStatus YearlyIncome Gender  TotalChildren  NumberChildrenAtHome  \
# 0             S      0-25000      F              2                     1
# 1             M  25001-50000      M              3                     0
# 2             M  25001-50000      F              2                     0
# 3             S      0-25000      M              2                     0
# 4             S  25001-50000      F              0                     0
#
#              Education      Occupation  HomeOwner CommuteDistance
# 0  Partial High School        Clerical       True      5-10 Miles
# 1      Partial College        Clerical      False      5-10 Miles
# 2          High School  Skilled Manual      False       0-1 Miles
# 3      Partial College          Manual      False       2-5 Miles
# 4      Partial College  Skilled Manual      False       0-1 Miles

# %%
data.shape
# Out:
# (4246, 15)

# %%
data.describe().transpose()
# Out:
#                        count          mean          std      min      25%  \
# CustomerID            4246.0  20164.814414  5397.956824  11001.0  15349.5
# TotalChildren         4246.0      1.622468     1.500829      0.0      0.0
# NumberChildrenAtHome  4246.0      0.745878     1.264800      0.0      0.0
#
#                           50%       75%      max
# CustomerID            20152.5  24966.25  29477.0
# TotalChildren             1.0      3.00      5.0
# NumberChildrenAtHome      0.0      1.00      5.0

# %%
data.columns
# Out:
# Index(['CustomerID', 'Title', 'FirstName', 'MiddleName', 'LastName',
#        'BirthDate', 'MaritalStatus', 'YearlyIncome', 'Gender', 'TotalChildren',
#        'NumberChildrenAtHome', 'Education', 'Occupation', 'HomeOwner',
#        'CommuteDistance'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4246 entries, 0 to 4245
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CustomerID            4246 non-null   int64
#  1   Title                 30 non-null     object
#  2   FirstName             4246 non-null   object
#  3   MiddleName            2404 non-null   object
#  4   LastName              4246 non-null   object
#  5   BirthDate             4246 non-null   object
#  6   MaritalStatus         4246 non-null   object
#  7   YearlyIncome          4246 non-null   object
#  8   Gender                4246 non-null   object
#  9   TotalChildren         4246 non-null   int64
#  10  NumberChildrenAtHome  4246 non-null   int64
#  11  Education             4246 non-null   object
#  12  Occupation            4246 non-null   object
#  13  HomeOwner             4246 non-null   bool
#  14  CommuteDistance       4246 non-null   object
# dtypes: bool(1), int64(3), object(11)
# memory usage: 468.7+ KB

# %%
data.nunique()
# Out:
# CustomerID              4246
# Title                      3
# FirstName                589
# MiddleName                34
# LastName                 267
# BirthDate               3402
# MaritalStatus              2
# YearlyIncome               5
# Gender                     2
# TotalChildren              6
# NumberChildrenAtHome       6
# Education                  5
# Occupation                 5
# HomeOwner                  2
# CommuteDistance            5
# dtype: int64

# %%
data.isnull().sum()
# Out:
# CustomerID                 0
# Title                   4216
# FirstName                  0
# MiddleName              1842
# LastName                   0
# BirthDate                  0
# MaritalStatus              0
# YearlyIncome               0
# Gender                     0
# TotalChildren              0
# NumberChildrenAtHome       0
# Education                  0
# Occupation                 0
# HomeOwner                  0
# CommuteDistance            0
# dtype: int64

# %%
data.drop(['CustomerID','FirstName','MiddleName','LastName'],'columns',inplace=True)

# %%
data.head(10)
# Out:
#   Title            BirthDate MaritalStatus YearlyIncome Gender  TotalChildren  \
# 0   NaN  1951-08-14 00:00:00             S      0-25000      F              2
# 1   NaN  1950-02-11 00:00:00             M  25001-50000      M              3
# 2   NaN  1957-09-21 00:00:00             M  25001-50000      F              2
# 3   NaN  1941-06-11 00:00:00             S      0-25000      M              2
# 4   NaN  1967-05-14 00:00:00             S  25001-50000      F              0
# 5   NaN  1975-11-01 00:00:00             S  25001-50000      F              0
# 6   NaN  1959-06-13 00:00:00             M  50001-75000      F              4
# 7   NaN  1936-06-16 00:00:00             S  25001-50000      M              2
# 8   NaN  1977-07-06 00:00:00             S  25001-50000      F              0
# 9   NaN  1966-05-14 00:00:00             M  25001-50000      M              1
#
#    NumberChildrenAtHome            Education      Occupation  HomeOwner  \
# 0                     1  Partial High School        Clerical       True
# 1                     0      Partial College        Clerical      False
# 2                     0          High School  Skilled Manual      False
# 3                     0      Partial College          Manual      False
# 4                     0      Partial College  Skilled Manual      False
# 5                     0          High School  Skilled Manual      False
# 6                     3           Bachelors     Professional       True
# 7                     0      Partial College        Clerical      False
# 8                     0  Partial High School        Clerical      False
# 9                     1           Bachelors   Skilled Manual       True
#
#   CommuteDistance
# 0      5-10 Miles
# 1      5-10 Miles
# 2       0-1 Miles
# 3       2-5 Miles
# 4       0-1 Miles
# 5       1-2 Miles
# 6       2-5 Miles
# 7      5-10 Miles
# 8       1-2 Miles
# 9       0-1 Miles

# %%
plt.figure(figsize=(10,6),dpi=300)
sns.displot(data=data,x='BirthDate',kde=True)

# %%
sns.histplot(data=data,x='MaritalStatus')
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='Count'>

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.countplot(x='TotalChildren',data=data)
# Out:
# <AxesSubplot:xlabel='TotalChildren', ylabel='count'>

# %%
sns.histplot(data=data,x='Gender')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Count'>

# %%
sns.histplot(data=data,x='NumberChildrenAtHome')
# Out:
# <AxesSubplot:xlabel='NumberChildrenAtHome', ylabel='Count'>

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.histplot(data=data,x='Education')
# Out:
# <AxesSubplot:xlabel='Education', ylabel='Count'>

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.histplot(data=data,x='Occupation')
# Out:
# <AxesSubplot:xlabel='Occupation', ylabel='Count'>

# %%
sns.histplot(data=data,x='HomeOwner')
# Out:
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <AxesSubplot:xlabel='HomeOwner', ylabel='Count'>

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.histplot(data=data,x='CommuteDistance')
# Out:
# <AxesSubplot:xlabel='CommuteDistance', ylabel='Count'>

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.histplot(data=data,x='YearlyIncome')
# Out:
# <AxesSubplot:xlabel='YearlyIncome', ylabel='Count'>

# %%
sns.set(style="white", color_codes=True)

# %%
sns.violinplot(x="NumberChildrenAtHome", y="CommuteDistance",data=data )
# Out:
# <AxesSubplot:xlabel='NumberChildrenAtHome', ylabel='CommuteDistance'>

# %%
sns.set(style="white", color_codes=True)

# %%
sns.violinplot(x="HomeOwner ", y="YearlyIncome",data=data )
# Out:
# <AxesSubplot:xlabel='NumberChildrenAtHome', ylabel='YearlyIncome'>

# %%
sns.set(style="white", color_codes=True)

# %%
sns.violinplot(x="Education", y="HomeOwner",data=data )
# Out:
# <AxesSubplot:xlabel='Education', ylabel='HomeOwner'>

# %%
sns.set(style="white", color_codes=True)

# %%
sns.violinplot(x="YearlyIncome", y="HomeOwner",data=data )
# Out:
# <AxesSubplot:xlabel='YearlyIncome', ylabel='HomeOwner'>
