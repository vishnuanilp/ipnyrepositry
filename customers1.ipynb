# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data= pd.read_csv("C:\\Users\\vishn\\Documents\\Customers.csv",engine="python")

# %%
data.head()
# Out:
#    CustomerID  FirstName MiddleName LastName            BirthDate  \
# 0       11004  Elizabeth        NaN  Johnson  1968-08-08 00:00:00
# 1       11006      Janet          G  Alvarez  1965-12-06 00:00:00
# 2       11007      Marco        NaN    Mehta  1964-05-09 00:00:00
# 3       11008        Rob        NaN  Verhoff  1964-07-07 00:00:00
# 4       11009    Shannon          C  Carlson  1964-04-01 00:00:00
#
#   MaritalStatus  YearlyIncome Gender  TotalChildren  NumberChildrenAtHome  \
# 0             S  75001-100000      F              5                     5
# 1             S   50001-75000      F              0                     0
# 2             M   50001-75000      M              3                     3
# 3             S   50001-75000      F              4                     4
# 4             S   50001-75000      M              0                     0
#
#     Education    Occupation  HomeOwner CommuteDistance  NumberOfPurchases  \
# ...

# %%
data.shape
# Out:
# (10000, 16)

# %%
data.describe().transpose()
# Out:
#                         count          mean          std         min  \
# CustomerID            10000.0  20325.469300  5275.706913  11004.0000
# TotalChildren         10000.0      2.072700     1.716132      0.0000
# NumberChildrenAtHome  10000.0      1.081300     1.534055      0.0000
# NumberOfPurchases     10000.0      2.251300     0.998222      1.0000
# ProfitGenerated       10000.0  12510.868637  9010.860651    796.1449
#
#                                25%         50%           75%         max
# CustomerID            15824.750000  20367.0000  24853.250000  29474.0000
# TotalChildren             0.000000      2.0000      4.000000      5.0000
# NumberChildrenAtHome      0.000000      0.0000      2.000000      6.0000
# NumberOfPurchases         2.000000      2.0000      3.000000      7.0000
# ProfitGenerated        5789.984275  10622.3929  17224.608875  61196.7654

# %%
data.columns
# Out:
# Index(['CustomerID', 'FirstName', 'MiddleName', 'LastName', 'BirthDate',
#        'MaritalStatus', 'YearlyIncome', 'Gender', 'TotalChildren',
#        'NumberChildrenAtHome', 'Education', 'Occupation', 'HomeOwner',
#        'CommuteDistance', 'NumberOfPurchases', 'ProfitGenerated'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CustomerID            10000 non-null  int64
#  1   FirstName             10000 non-null  object
#  2   MiddleName            5730 non-null   object
#  3   LastName              10000 non-null  object
#  4   BirthDate             10000 non-null  object
#  5   MaritalStatus         10000 non-null  object
#  6   YearlyIncome          10000 non-null  object
#  7   Gender                10000 non-null  object
#  8   TotalChildren         10000 non-null  int64
#  9   NumberChildrenAtHome  10000 non-null  int64
#  10  Education             10000 non-null  object
#  11  Occupation            10000 non-null  object
#  12  HomeOwner             10000 non-null  bool
#  13  CommuteDistance       10000 non-null  object
#  14  NumberOfPurchases     10000 non-null  int64
# ...

# %%
data.nunique()
# Out:
# CustomerID              10000
# FirstName                 628
# MiddleName                 37
# LastName                  317
# BirthDate                6105
# MaritalStatus               2
# YearlyIncome                5
# Gender                      2
# TotalChildren               6
# NumberChildrenAtHome        7
# Education                   5
# Occupation                  5
# HomeOwner                   2
# CommuteDistance             5
# NumberOfPurchases           7
# ProfitGenerated          9999
# dtype: int64

# %%
data.isnull().sum()
# Out:
# CustomerID                 0
# FirstName                  0
# MiddleName              4270
# LastName                   0
# BirthDate                  0
# MaritalStatus              0
# YearlyIncome               0
# Gender                     0
# TotalChildren              0
# NumberChildrenAtHome       0
# Education                  0
# Occupation                 0
# HomeOwner                  0
# CommuteDistance            0
# NumberOfPurchases          0
# ProfitGenerated            0
# dtype: int64

# %%
data.drop(['CustomerID','FirstName','MiddleName','LastName'],'columns',inplace=True)

# %%
data.head(10)
# Out:
#              BirthDate MaritalStatus  YearlyIncome Gender  TotalChildren  \
# 0  1968-08-08 00:00:00             S  75001-100000      F              5
# 1  1965-12-06 00:00:00             S   50001-75000      F              0
# 2  1964-05-09 00:00:00             M   50001-75000      M              3
# 3  1964-07-07 00:00:00             S   50001-75000      F              4
# 4  1964-04-01 00:00:00             S   50001-75000      M              0
# 5  1963-11-04 00:00:00             M   50001-75000      M              4
# 6  1968-01-18 00:00:00             M  75001-100000      F              2
# 7  1968-08-06 00:00:00             M  75001-100000      M              2
# 8  1968-05-09 00:00:00             S  75001-100000      F              3
# 9  1979-02-27 00:00:00             S   25001-50000      F              0
#
#    NumberChildrenAtHome        Education      Occupation  HomeOwner  \
# 0                     5       Bachelors     Professional       True
# ...

# %%
plt.figure(figsize=(10,6),dpi=300)
sns.displot(data=data,x='BirthDate',kde=True)

# %%
sns.distplot(data.ProfitGenerated,kde=False)
# Out:
# C:\Users\vishn\New folder\ANCONDA\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='ProfitGenerated'>

# %%
sns.histplot(data=data,x='MaritalStatus')
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='Count'>

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.countplot(x='TotalChildren',data=data)
# Out:
# <AxesSubplot:xlabel='TotalChildren', ylabel='count'>

# %%
sns.histplot(data=data,x='Gender')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Count'>

# %%
sns.histplot(data=data,x='NumberChildrenAtHome')
# Out:
# <AxesSubplot:xlabel='NumberChildrenAtHome', ylabel='Count'>

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.histplot(data=data,x='Education')
# Out:
# <AxesSubplot:xlabel='Education', ylabel='Count'>

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.histplot(data=data,x='Occupation')
# Out:
# <AxesSubplot:xlabel='Occupation', ylabel='Count'>

# %%
sns.histplot(data=data,x='HomeOwner')
# Out:
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <AxesSubplot:xlabel='HomeOwner', ylabel='Count'>

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.histplot(data=data,x='CommuteDistance')
# Out:
# <AxesSubplot:xlabel='CommuteDistance', ylabel='Count'>

# %%
sns.countplot(x='NumberOfPurchases',data=data)
# Out:
# <AxesSubplot:xlabel='NumberOfPurchases', ylabel='count'>

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.histplot(data=data,x='ProfitGenerated',kde=True)
# Out:
# <AxesSubplot:xlabel='ProfitGenerated', ylabel='Count'>

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.histplot(data=data,x='YearlyIncome')
# Out:
# <AxesSubplot:xlabel='YearlyIncome', ylabel='Count'>

# %%
mean= np.mean(data['ProfitGenerated'])
mean
# Out:
# 12510.86863702002

# %%
sns.set(style="white", color_codes=True)

# %%
sns.violinplot(x="NumberChildrenAtHome", y="CommuteDistance",data=data )
# Out:
# <AxesSubplot:xlabel='NumberChildrenAtHome', ylabel='CommuteDistance'>

# %%
sns.set(style="white", color_codes=True)

# %%
sns.violinplot(x="YearlyIncome", y="HomeOwner",data=data )
# Out:
# <AxesSubplot:xlabel='YearlyIncome', ylabel='HomeOwner'>

# %%
sns.set(style="white", color_codes=True)

# %%
sns.violinplot(x="Education", y="HomeOwner",data=data )
# Out:
# <AxesSubplot:xlabel='Education', ylabel='HomeOwner'>

# %%
sns.set(style="white", color_codes=True)

# %%
sns.violinplot(x="NumberChildrenAtHome", y="CommuteDistance",data=data )
# Out:
# <AxesSubplot:xlabel='NumberChildrenAtHome', ylabel='CommuteDistance'>
